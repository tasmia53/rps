# %%
import random

choices = ["Rock", "Paper", "Scissors"]

def choice():
    selection = random.choice(choices)
    return selection

def winner(player1, computer):
    if player1 == "Rock" and computer == "Rock":
        result = "Tie"
    elif player1 == "Rock" and computer == "Paper":
        result = "computer wins"
    elif player1 == "Rock" and computer == "Scissors":
        result = "Player 1 wins"
    elif player1 == "Paper" and computer == "Paper":
        result = "Tie"
    elif player1 == "Paper" and computer == "Rock":
        result = "Player 1 wins"
    elif player1 == "Paper" and computer == "Scissors":
        result = "computer wins"
    elif player1 == "Scissors" and computer == "Scissors":
        result = "Tie"
    elif player1 == "Scissors" and computer == "Rock":
        result = "computer wins"
    elif player1 == "Scissors" and computer == "Paper":
        result = "Player 1 wins"
    return result

player_1_wins = 0
computer_wins = 0

while player_1_wins != 2 and computer_wins != 2:
    player_1 = choice()
    computer = choice()
    winr = winner(player_1, computer)
    print("Player 1 plays %s" % player_1)
    print("computer plays %s" % computer) 
    print(winr)
    # Here's where we'll overwrite the counts of the wins to determine best two of three
    if winr == "Player 1 wins":
        player_1_wins = player_1_wins + 1
        print("Player 1 total wins: %i" % player_1_wins)
    elif winr == "computer wins":
        computer_wins = computer_wins + 1 
        print("computer total wins: %i" % computer_wins)
    else:
        pass
# Out:
# Player 1 plays Rock
# computer plays Rock
# Tie
# Player 1 plays Scissors
# computer plays Paper
# Player 1 wins
# Player 1 total wins: 1
# Player 1 plays Paper
# computer plays Rock
# Player 1 wins
# Player 1 total wins: 2

# %%
choices = ["Rock", "Paper", "Scissors"]

def choice():
    selection = random.choice(choices)
    return selection

def winner(player1, computer):
    if player1 == computer:
        result = "Tie"
    elif player1 == "Rock" and computer == "Paper":
        result = "Player 2 wins"
    elif player1 == "Rock" and computer == "Scissors":
        result = "Player 1 wins"
    elif player1 == "Paper" and computer == "Rock":
        result = "Player 1 wins"
    elif player1 == "Paper" and computer == "Scissors":
        result = "computer wins"
    elif player1 == "Scissors" and computer == "Rock":
        result = "computer wins"
    elif player1 == "Scissors" and computer == "Paper":
        result = "computer wins"
    return result

player_1_wins = 0
computer_wins = 0

while player_1_wins != 2 and computer_wins != 2:
    player_1 = choice()
    computer = choice()
    winr = winner(player_1, computer)
    print("Player 1 plays %s" % player_1)
    print("Player 2 plays %s" % computer) 
    print(winr)
    # Here's where we'll overwrite the counts of the wins to determine best two of three
    if winr == "Player 1 wins":
        player_1_wins = player_1_wins + 1
        print("Player 1 total wins: %i" % player_1_wins)
    elif winr == "computer wins":
        player_2_wins = computer_wins + 1 
        print("Player 2 total wins: %i" % player_2_wins)
    else:
        pass
# Out:
# Player 1 plays Rock
# Player 2 plays Paper
# Player 2 wins
# Player 1 plays Paper
# Player 2 plays Scissors
# computer wins
# Player 2 total wins: 1
# Player 1 plays Rock
# Player 2 plays Rock
# Tie
# Player 1 plays Paper
# Player 2 plays Scissors
# computer wins
# Player 2 total wins: 1
# Player 1 plays Scissors
# Player 2 plays Paper
# computer wins
# Player 2 total wins: 1
# Player 1 plays Scissors
# Player 2 plays Paper
# computer wins
# Player 2 total wins: 1
# Player 1 plays Rock
# Player 2 plays Scissors
# Player 1 wins
# Player 1 total wins: 1
# Player 1 plays Rock
# Player 2 plays Scissors
# Player 1 wins
# Player 1 total wins: 2

# %%
import random

choices = ["Rock", "Paper", "Scissors"]

def choice():
    selection = random.choice(choices)
    return selection

def winner(player1, player2):
    if player1 == "Rock" and computer == "Rock":
        result = "Tie"
    elif player1 == "Rock" and computer == "Paper":
        result = "computer wins"
    elif player1 == "Rock" and computer == "Scissors":
        result = "Player 1 wins"
    elif player1 == "Paper" and computer == "Paper":
        result = "Tie"
    elif player1 == "Paper" and computer == "Rock":
        result = "Player 1 wins"
    elif player1 == "Paper" and computer == "Scissors":
        result = "computer wins"
    elif player1 == "Scissors" and computer == "Scissors":
        result = "Tie"
    elif player1 == "Scissors" and computer == "Rock":
        result = "computer wins"
    elif player1 == "Scissors" and computer == "Paper":
        result = "Player 1 wins"
    return result

player_1_wins = 0
computer_wins = 0
ties = 0

for i in range(1000000):
    player_1 = choice()
    computer = "Scissors"
    winr = winner(player_1, computer)
    #print("Player 1 plays %s" % player_1)
    #print("computer plays %s" % computer) 
    #print(winr)
    # Here's where we'll overwrite the counts of the wins to determine best two of three
    if winr == "Player 1 wins":
        player_1_wins = player_1_wins + 1
        #print("Player 1 total wins: %i" % player_1_wins)
    elif winr == "computer wins":
        computer_wins = computer_wins + 1 
        #print("computer total wins: %i" % computer_wins)
    else:
        ties = ties + 1

print("Player 1 won %s games. computer won %s. There were %s ties." % (player_1_wins, computer_wins, ties))
# Out:
# Player 1 won 333049 games. computer won 333337. There were 333614 ties.
